# %%
# For debug mode
# %load_ext autoreload
# %autoreload 2

# %%
wig_list_paths = [
    "../database/company_list/wig_chemia.csv",
    "../database/company_list/wig_odziez.csv",
    "../database/company_list/wig_spozywczy.csv",
]

# %%
import pandas as pd
import scripts as ds



f = ds.FinancialReport(["PKN"])
s = ds.Scraper(f)
s.scrape()

# %%
name_scraper = ds.NameScraper()
name_scraper.cast_name(TICKER_WIG_CHEMIA)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 name_scraper = ds.NameScraper()
# ----> 2 name_scraper.cast_name(TICKER_WIG_CHEMIA)
#
# File ~/Dokumenty/StudiaZDM/impactOfFinancialReport/dataScrapers/scripts/name_scraper.py:32, in NameScraper.cast_name(self, ticker_names)
#      30 def cast_name(self, ticker_names: list) -> list:
#      31     for t in ticker_names:
# ---> 32         self._scrap_name(t)
#
# File ~/Dokumenty/StudiaZDM/impactOfFinancialReport/dataScrapers/scripts/name_scraper.py:24, in NameScraper._scrap_name(self, ticker_name)
#      23 def _scrap_name(self, ticker_name: str) -> str:
# ---> 24     page = self._request_page("{}{}".format(NameScraper.MAIN_URL,
#      25                                             ticker_name))
#      26     print(page.prettify())
#      27     header = page.find("font", attrs={"id": "f18"})
#
# ...

# %%
from bs4 import BeautifulSoup



print(soup.prettify())
# Out:
# <html>
#  <head>
#   <link href="https://fonts.googleapis.com/css?family=Archivo:400,500|Arimo:400,500|Bitter:400,500|EB+Garamond:400,500|Lato|Libre+Baskervill|Libre+Franklin:400,500|Lora:400,500|Google+Sans:regular,medium:400,500|Material+Icons|Google+Symbols|Merriweather|Montserrat:400,500|Mukta:400,500|Muli:400,500|Nunito:400,500|Open+Sans:400,500,600|Open+Sans+Condensed:400,600|Oswald:500|Playfair+Display:400,500|Poppins:400,500|Raleway:400,500|Roboto:400,500|Roboto+Condensed:400,500|Roboto+Slab:400,500|Slabo+27px|Source+Sans+Pro|Ubuntu:400,500|Volkhov&amp;display=swap" rel="stylesheet"/>
#   <script>
# ...
